# %% [markdown]
# # Computer Network

# %% [markdown]
# The internet is a computer network that interconnect millions of devices (end systems or host) throughout the world.
#
# - End systems are connected together by a network of communication link (copper wire, optical fiber) and `packet` `switch`.
# - Different links transmit at different rate (`transmission rate` bits/second)
# - When a end system has to send data to another end system, the sending end system segment the data and adds header bytes to each segment. The resulting packages of information, known as `packets` are sent through the network to destiantion end system where are reassembled into original data
# - A *packet switch* takes a packet arriving on one of its incomming communication links and *forward* that packet on one its outgoing communication. The most used are *routers* or *link-layer switches* that take these and forward to destination.
# - The sequence traversed by a packet from the sending end system to the receiving and system is known as a **route** or path.
# - End system access the internet through *Internet Service Providers* (IPS), each IPS is itself a network of packet switches and communication links.

# %% [markdown]
# - Providers deliver services such as DSL (bandwith for your subscribers), high-speed local area network access () and mobile wireless access.
# - IPS also provide Internet access to content providers,
# connecting Web sites and video servers directly to the Internet.
# - *End systems*, packet switches, and other pieces of the Internet run protocols that control the sending
# and receiving of information within the Internet. The Transmission Control Protocol (TCP) and the
# Internet Protocol (IP) are two of the most important protocols in the Internet.
# -  The IP protocol specifies the format of the packets that are sent and received among routers and end systems. The Internet’s principal protocols are collectively known as TCP/IP.

# %% [markdown]
# ## What Is a Protocol?

# %% [markdown]
# > A protocol defines the format and order of messages exchanged between two and more communicating entities , as weel as the actions taken on the transmission and/or receipt of a message or event.
# >

# %% [markdown]
# *Network protocol*
#
# All activity in the Internet that involves two or more communicating remote entities is governed by a protocol.
# - Congestion-control protocols in end systems control the rate at which packets
# are transmitted between sender and receiver;
# - Protocols in routers determine a packet’s path from
# source to destination.

# %% [markdown]
# ### The Network Edge

# %% [markdown]
# The computers and other devices connected to the Internet are often referred to as *end systems*. They are referred to as end systems because they sit at the edge of the Internet.
#
# `End systems = host` (host application program such as a web browser program, web server program, an email server program).
#
# Hosts are sometimes further divided into two categories: *clients* and *servers*. Informally, clients tend to be desktop and mobile PCs, smartphones, and so on, whereas servers tend to be more powerful machines that store and distribute
# Web pages, stream video, relay e-mail, and so on. Today, most of the servers from which we receive
# search results, e-mail, Web pages, and videos reside in large data centers

# %% [markdown]
# The network that physically connects an end system to the first router (also known as the “edge router”) on a path from the end system to any other distant end system.

# %%
import urllib.request
import urllib.parse

# %%
req = urllib.request.Request(
    url="https://docs.docker.com/desktop/install/linux-install/#system-requirements",
    data=None,           # if the reuest data
    unverifiable=False,
    method='GET')

with urllib.request.urlopen(req, timeout=1) as docs:
    status = docs.status
    print("status:", status)
    data = (docs.read().decode())
    print(data[10:50])

# %%
req

# %%
ss.getcode()
# Out:
# 200

# %%
ss.headers.items()
# Out:
# [('Content-Type', 'text/html'),
#  ('Content-Length', '171890'),
#  ('Connection', 'close'),
#  ('x-amz-id-2',
#   'cdveySB67y0PtZVPbUVaEf2cxxCLWDsTqaKqEvZz21hdLNfT0p4IzuNCY7ppzjI89xVLxIWKIt4='),
#  ('x-amz-request-id', 'PQRGXW1H8QAW1QZZ'),
#  ('Last-Modified', 'Fri, 08 Dec 2023 00:55:20 GMT'),
#  ('Server', 'AmazonS3'),
#  ('Date', 'Sat, 09 Dec 2023 02:24:08 GMT'),
#  ('ETag', '"7380331652cb9069d6d32abfbba3f3f0"'),
#  ('Vary', 'Accept-Encoding'),
#  ('X-Cache', 'Hit from cloudfront'),
#  ('Via', '1.1 987f534b007adf9f05532207c167c9c8.cloudfront.net (CloudFront)'),
#  ('X-Amz-Cf-Pop', 'LIM50-P2'),
#  ('X-Amz-Cf-Id', '51dZU5-obQy0jQN8IKWo9vPxw1qLntUBd6KTWKLAv1iqw19W6boQ4A=='),
#  ('Age', '5814')]

# %%
type(ss)
# Out:
# http.client.HTTPResponse

# %%
dd = ss.read()

# %%
print(dd.decode())
# Out:
# <!doctype html><html lang=en><head><meta charset=utf-8><meta name=viewport content="width=device-width,initial-scale=1"><title>Install Docker Desktop on Linux | Docker Docs</title><meta name=description content="Install Docker on Linux with ease using our step-by-step installation guide covering system requirements, supported platforms, and where to go next."><meta name=keywords content="[linux,docker linux install,docker linux,linux docker installation,docker for linux,docker desktop for linux,installing docker on linux,docker download linux,how to install docker on linux]"><link rel=canonical href=https://docs.docker.com/desktop/install/linux-install/><link rel=icon type=image/x-icon href=https://docs.docker.com/assets/favicons/docs@2x.ico sizes=129x128><link rel=apple-touch-icon type=image/x-icon href=https://docs.docker.com/assets/favicons/docs@2x.ico sizes=129x128><meta name=msapplication-TileImage content="https://docs.docker.com/assets/favicons/docs@2x.ico"><meta property="og:
# ...

# %%
with urllib.request.urlopen(
    "https://docs.docker.com/desktop/install/linux-install/#system-requirements") as docs:
    status = docs.status
    print("status:", status)
    data = (docs.read().decode())
    print(data[10:50])
# Out:
# status: 200
# html><html lang=en><head><meta charset=u

# %% [markdown]
# `urllib.request.urlopen` return `http.client.HTTPResponse` object
# - `connection:close`: means the connection will be closed after completion of the
# response. In either the request or the response header fields indicates that the connection SHOULD NOT be considered `persistent' (section 8.1) after the current request/response is complete.

# %% [markdown]
# - `docs`:
